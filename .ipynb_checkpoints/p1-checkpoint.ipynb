# %%
# %matplotlib inline
import matplotlib
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
def idm(dim,width=0):
    M1 = np.tri(dim,dim,width)
    M2 = np.tri(dim,dim,-width-1)
    M3 = np.ones([dim,dim])
    M4 = M3 - M2
    M5 = np.multiply(M1,M4)
    return M5

# %% [markdown]
# # Original version - Single Prox PAPC
# PAPC is designed to solve a minmax problem, i.e. finding a saddle point for problems of the form:
# $$ \min_u \max_v \{K(u,v)\} = \min_u \max_v \left\{f(u) + \left<M^Tu,v\right> - g(v)\right\} $$
# Where:
# * $f$ has a $L_f$ lipshitz gradient
# * $g$ is LSC not
# * Both are convex, proper
#
# ### PAPC
# * $p^{k+1} = u^k -\tau\left(Mv^k+\nabla f(u^k)\right)$
# * $v^{k+1} = prox_{g,\sigma}\left(v^k+\frac{1}{\sigma}M^T p^{k+1}\right)$
# * $u^{k+1} = u^k -\tau\left(Mv^{k+1}+\nabla f(u^k)\right)$

# %% [markdown]
# ### Convergence
# A point $\left(\tilde(u),\tilde{v}\right)$ is a saddle point of K if $\forall u,v \quad K(\tilde{u},v)\leq K(\tilde{u},\tilde{v}) \leq K(u,\tilde{v})$
#
# A point $\left(\tilde(u),\tilde{v}\right)$ is a $\varepsilon$-saddle point of K if $\forall u \quad K(\tilde{u},v)-\varepsilon\leq K(\tilde{u},\tilde{v}) \leq K(u,\tilde{v})+\varepsilon$
#
# Note that any point $\left(\tilde{u},\tilde{v}\right)$ which hold $\forall u,v \quad K\left(\tilde{u},v\right)-K\left(u,\tilde{v}\right)\leq\varepsilon$ is a $\varepsilon$-saddle point of K.
#
# [DST15] Theorem 3.1: Let $\left\{\left(p^k,v^k,u^k\right)\right\}_{k\in\mathbb{N}}$ be the sequence generated by the PAPC algorithm with $\tau L_f\leq 1$ and $\tau\sigma\lVert M^TM\rVert\leq 1$. Then $G:=\sigma I -\tau M^TM$ is positive semidefinite and for every $u,v$ we have $$K\left(\bar{u}^N,v\right)-K\left(u,\bar{v}^N\right)\leq\frac{\tau^-1\left\lVert u-u^0\right\rVert^2+\left\lVert v-v^0\right\rVert_G^2}{2N}$$

# %% [markdown]
# ## ALMA & PAPC - the underlying PG term
# ### Dual Problem
# Consider the dual problem
# $$\max_v\min_u\{f(u)+<M^Tu,v>-g(v)\}$$
# $$=\max_v\{-g(v)-\max_u\{<u,-Mv> - f(u)\}\}$$
# $$=\max_v\{-g(v)-f^*(-Mv)\}$$
# $$=-\min_v\{g(v)+f^*(-Mv)\}$$
# We drop the sign because we are interested in the argmin and get:
# $$\text{(DM1)}\min_v\{g(v)+f^*(w)\mid Mv+w=0\}$$
#
# ### Lagrangian
# * The lagrngian is $L(w,v,c)=f^*(w)+g(v)-<c,Mv+w>$
# * And the augmented lagrangian: $L_t(w,v,c)=f^*(w)+g(v)-<c,Mv+w>+\frac{t}{2}\lVert Mv+w \rVert ^2$
#
# ### ALMA
# * $w^{k+1}\in\arg\min_w L(w,v^k,c^k) = \arg\min_w\{f^*(w)-<c^k,w>\}$
# * $v^{k+1}\in\arg\min_v L_t(w^{k+1},v,c^k)=\arg\min_v\{g(v)-<c^k,Mv>+\frac{t}{2}\lVert Mv+w^{k+1} \rVert^2 \}$
# * $c^{k+1}=c^k-t(Mv^{k+1}+w^{k+1})$
#
# #### From ALMA to PAPC
# We first note that $w^{k+1}=\nabla f(c^k)$. This is because:
# 1. From 1st order optimality condition :$0\in \partial f^*(w^{k+1})-c^k$
# 2. [why?] This imply that $\partial w^{k+1} \in f^{**}(c^k)$
# 3. Since $f$ is LSC, $f^{**}=f$
# 4. $f$ is Lipschitz so smooth, hence $\partial f = \nabla f$
#
# Thus ALMA can be rewritten for this case as:
# * $v^{k+1}\in\arg\min_v\{g(v)-<c^k,Mv>+\frac{t}{2}\lVert Mv+\nabla f(c^k) \rVert^2 \}$
# * $c^{k+1}=c^k-t(Mv^{k+1}+\nabla f(c^k))$
#
# In this reduced formulation, the first part, namely finding $v^{k+1}$, might be hard to compute exactly. It is possible to ease the effort by finding an approximate solution. This can be done using the Proximal Gradient (PG) method:
#
# 1. define $P_k=\frac{\tau}{2}\lVert Mv +\nabla f(c^k) -\frac{1}{\tau}c^k\rVert^2$
# 2. note that $v^{k+1}=\arg\min_v\{g(v)+P_k(v)\}$ since the difference is in non $v$ terms
# 3. use PG on this new formulation:
#     1. $v^{k+1}=prox_{g,\sigma}(v^k-\frac{1}{\sigma}(\nabla_v P_k(v^k))$
#     2. $v^{k+1}=\arg\min_v\{g(v)+\frac{\sigma}{2}\lVert v- (v^k-\frac{1}{\sigma}\nabla_vP_k(v^k))\rVert^2\}$
# 4. $\nabla_vP_k(v)=\tau M^T (Mv +\nabla f(c^k) -\frac{1}{\tau}c^k)$
# 5. define $p^{k+1}=c^k-\tau(Mv+\nabla f(c^k))$, so $\nabla_vP_k(v)=-M^Tp^{k+1}$
# 6. this define the PG step for the approximate $v^{k+1}$ as:
#     1. $p^{k+1}=c^k-\tau(Mv+\nabla f(c^k))$
#     2. $v^{k+1}=prox_{g,\sigma}(v^k+\frac{1}{\sigma}M^Tp^{k+1})$
#
# This is exactly PAPC with $u^k = c^k$ !
#
# The aim of the following work is to capitulate on this observation in order to find better approximations for the $v^k$ phase and thus to accelerate PAPC.

# %% [markdown]
# # Case Study
# $$ \min_u H(u) := \min_u \{ \lVert Au-b \rVert ^2 + \lVert Mu \rVert_1 \} $$

# %% [markdown]
# ## MinMax Formulation
# $$ \min_u \max_v \{\lVert Au-b \rVert ^2 + <u,M^Tv> -\delta_{B_{\infty,1}} (v)\} $$
#
# Since $\max_y\{<x,y>-\delta_{B_{\infty,1}}(y)\} = \sum_i x_i\times sign(x_i) = \lVert x \rVert_1$

# %% [markdown]
# ## Functions
# * $ f(u) = \lVert Au-b \rVert^2 $
# * $ g(v) = \delta_{B_{\infty,1}} $

# %%
# total variation matrix
def TV(dim):
    M1 = np.eye(dim-1,dim,0)
    M2 = np.eye(dim-1,dim,1)
    return M1 - M2
# objective
def H(A,b,M):
    def h(u):
        return np.linalg.norm(np.dot(A,u)-b)**2 + np.sum(np.fabs(np.dot(M,u)))
    return h

# %%
# create problem

def initProblem(dim1,dim2):
    A = np.random.rand(dim1,dim2)
    x = np.random.rand(dim2,1)
    b = np.dot(A,x)
    print(np.linalg.norm(np.dot(np.transpose(A),A)))
   
    z = np.matrix(np.zeros((dim2-1,1),dtype=np.int)) 
    M1 = np.concatenate((-1*np.identity(dim2-1,dtype=np.int),z),axis=1)
    M2 = np.concatenate((z,np.identity(dim2-1,dtype=np.int)),axis=1)
    M = M1 + M2
    
    def H(u):
        H1 = (np.linalg.norm(np.dot(A,u)-b,2))**2
        H2 = np.linalg.norm(np.dot(M,u),1)
        return H1 + H2
    
    return{'A':A,'x':x,'b':b, 'M':M, 'H':H}

# %% [markdown]
# # Single Prox PAPC implementation
#
# * $ p^{k+1} = u^k -\tau (M^T v^k + \nabla f(u^k)) $
# * $ v^{k+1} = prox_{g,\sigma}(v^k + \frac{1}{\sigma}Mp^{k+1}) $
# * $ u^{k+1} = u^k -\tau (M^T v^{k+1} + \nabla f(u^k)) $

# %%
# prox operator
def prox(x):
    d = np.shape(x)
    y=x
    for j in range(0,d[0]):
        if x[j,0] > 1:
            y[j,0] = 1
            
        elif x[j,0] < -1:
            y[j,0] = -1
    return(y)

# %%
# single prox papc implementation
def papc1(A,b,M,N,v0,u0):
    
    # initialization
    v = v0
    u = u0
    Mt = np.transpose(M)
    A2 = np.dot(np.transpose(A),A)
    Ab = np.dot(np.transpose(A),b)
    t = 1/(2*np.linalg.norm(A2))
    s = t*(np.linalg.norm(M,2))**2
    P = []
    V = []
    U = []
    print(t)
    # iterations
    for i in range(0,N):
        p = u-t*(np.dot(Mt,v) + 2*np.dot(A2,u) - 2*Ab )
        a = v + s*np.dot(M,p)
        v = prox(a)
        u = u-t*(np.dot(Mt,v) + 2*np.dot(A2,u) - 2*Ab )
        P.append(p)
        V.append(v)
        U.append(u)
        
    return{'P':P,'V':V,'U':U}

# %%
# get meaningful results
def getResults(res,accuracy,H,optimum=np.inf):
    try:
        U = res['U']
    except TypeError:
        U = res
    
    # when no optimum value is given, first find H(u) for all u in U, then find minimal iteration and compare to it.
    # go over all iterations again and find the first that is accurate enough
    if optimum==np.inf:
        
        # find H result for all iterations
        H_results = []
        for u in U:
            H_results.append(H(u))

        optarg = np.argmin(H_results)
        optval = H_results[optarg]

        # find first iteration that is accurate enough    
        i = 0
        for h in H_results:
            i = i + 1
            if (h-optval) <= accuracy:
                return [i,optarg,h,optval]

    
    # when optimum is given, get results until first that is accurate enough
    else:
        optarg = Null
        optval = optimum
        for u in U:
            i = i + 1
            h = H(u)
            if (h-optval) <= accuracy:
                return [i,optarg,h,optval]
            
    return [np.inf,optarg,np.inf,optval]

# %% [markdown]
# ## Simulation

# %%
# actual problem creation
problem_dimension = 30
R = initProblem(problem_dimension,problem_dimension)
A = R['A']
M = R['M']
b = R['b']
H = R['H']

# %%
# simulation
u0 = np.matrix(np.zeros((problem_dimension,1),dtype = np.int))
v0 = np.matrix(np.zeros((problem_dimension-1,1),dtype = np.int))

papc1_results = papc1(A,b,M,10000,v0,u0)
U = papc1_results['U']
H_results = []
for u in U:
    H_results.append(H(u))

# %%
# results
plt.plot(H_results)

# %%
# complete trial
def completeTrialPapc1(problem_dimension,optimality_iter_count,accuracy):
    
    # create problem
    problem = initProblem(problem_dimension,problem_dimension)
    
    # run papc1
    u0 = np.matrix(np.zeros((problem_dimension,1),dtype = np.int))
    v0 = np.matrix(np.zeros((problem_dimension-1,1),dtype = np.int))
    results = papc1(problem['A'],problem['b'],problem['M'],optimality_iter_count,v0,u0)
    
    # final results,dz 3no i
    U = results['U']
    return getResults(U,accuracy,problem['H'])

# %%
completeTrialPapc1(10,5000,0.001)
# Out:
# [765, 4825, 0.61563030433388244, 0.61466816542875535]

# %% [markdown]
# # Multi prox PAPC
# in each cycle, the $p$ and $v$ updates more than once

# %%
# multi prox papc implementation
def papc2(L,A,b,M,N,v0,u0,optimum=[]):
    
    # initialization
    v = v0
    u = u0
    Mt = np.transpose(M)
    A2 = np.dot(np.transpose(A),A)
    Ab = np.dot(np.transpose(A),b)
    t = 1/(2*np.linalg.norm(A2,2))
    if t > 1:
        t = np.random.rand(1)[0]
    s = t*(np.linalg.norm(M,2))**2
    V = []
    U = []
    print(t)
    
    # iterations
    for i in range(0,N):
        p = u
        for j in range(0,L):
            p = p-t*(np.dot(Mt,v) + 2*np.dot(A2,p) - 2*Ab )
            a = v + s*np.dot(M,p)
            v = prox(a)
        u = u-t*(np.dot(Mt,v) + 2*np.dot(A2,u) - 2*Ab )
        V.append(v)
        U.append(u)
        
        # when optimality conditions are given, stop when accuracy is reached
        if optimum!=[]:
            h = optimum[2](u)
            if (h-optimum[0]) <= optimum[1]:
                return{'V':V,'U':U,'optval':h}
        
    return{'V':V,'U':U,'optval':None}

# %%
# compare papc2 different Ls
# since papc1 is like papc2 with L=1, this allows comparison between papc1 and papc2
def compPapc2(problem_dimension,optimality_iter_count,accuracy,papc2L):
    # 
    results = []
    
    # create problem
    problem = initProblem(problem_dimension,problem_dimension)
    
    # initial vectors
    u0 = np.matrix(np.zeros((problem_dimension,1),dtype = np.int))
    v0 = np.matrix(np.zeros((problem_dimension-1,1),dtype = np.int))

    # run papc1 for optimaity_iter_count iterations to find optimum
    p1r = getResults(papc1(problem['A'],problem['b'],problem['M'],optimality_iter_count,v0,u0),accuracy,problem['H'])
    # create optimum ref for papc2
    optimum = [p1r[3],accuracy,problem['H']]
    
    # run papc2
    for L in papc2L:
        p2results = papc2(L,problem['A'],problem['b'],problem['M'],optimality_iter_count,v0,u0,optimum)
        #results.append(getResults(p2results['U'],accuracy,problem['H']))
        results.append(np.shape(p2results['U']))
        #results.append(p2results)
    
    return results

# %%
L = range(1,11)
p2r = compPapc2(100,5000,0.0001,L)
p2rm = np.matrix(p2r)

# %% [markdown]
# ### Number of PAPC iterations

# %%
plt.plot(L,p2rm[:,0])

# %% [markdown]
# ### Number of prox operations

# %%
prox_iters = np.multiply(p2rm[:,0],np.transpose(np.matrix(L)))
plt.plot(L,prox_iters)

# %% [markdown]
# it is evident that even though the total amount of PAPC iterations is diminished, the total number of prox iterations - which we take to be the hardest part in each iteration - actually increases!

# %%
def plotCompPapc2(problem_dimension,N,papc2L):
    # create problem
    problem = initProblem(problem_dimension,problem_dimension)
    
    # initial vectors
    u0 = np.matrix(np.zeros((problem_dimension,1),dtype = np.int))
    v0 = np.matrix(np.zeros((problem_dimension-1,1),dtype = np.int))

    # run papc2
    L_str = []
    for L in papc2L:
        p2results = papc2(L,problem['A'],problem['b'],problem['M'],N,v0,u0,[])
        h = []
        for u in p2results['U']:
            h.append(problem['H'](u))
        plt.plot(h)
        plt.hold(True)
        L_str.append(str(L))
    plt.hold(False)
    plt.legend(L_str)

# %%
plotCompPapc2(5,300,[1,2,3,4,5])
# Out:
# 6.7552081054
# 0.0748220392508
# 0.0748220392508
# 0.0748220392508
# 0.0748220392508
# 0.0748220392508

# %%
plotCompPapc2(50,20000,[1,2])
# Out:
# 627.827699047
# 0.000798075921907
# 0.000798075921907

# %%
plotCompPapc2(500,10000,[1,2,3,4,5])
# Out:
# 62717.5058157
# 7.97399981476e-06

# %% [markdown]
# ## Lenna tests

# %%
from scipy import misc
lenna = sp.misc.imread('lenna_bw.jpg')
a = 30
lenna_bw = lenna[a:-a,a:-a,0]
del a
del lenna
lenna_dim = lenna_bw.shape[0]
print(lenna_dim)
plt.imshow(lenna_bw,cmap='gray')
# Out:
# 324

# %%
def downscale(inp,r):
    d = int(inp.shape[0]/r)
    outp = np.zeros([d,d])
    for i in range(d):
        for j in range(d):
            outp[i,j] = np.mean(inp[i*r:(i+1)*r,j*r:(j+1)*r])
    return outp
lenna_bw = downscale(lenna_bw,6)
lenna_dim = lenna_bw.shape[0]
print(lenna_dim)
plt.imshow(lenna_bw,cmap='gray')
# Out:
# 54

# %%
lenna_orig = np.reshape(lenna_bw,[lenna_dim**2,1])

# %%
A = np.dot(np.transpose(idm(lenna_dim**2,3)),idm(lenna_dim**2,3))
lenna_b = np.dot(A,lenna_orig)
plt.imshow(np.reshape(lenna_b,[lenna_dim,lenna_dim]),cmap='gray')

# %%
print(lenna_b.shape)
lenna_n = lenna_b + np.random.randn(lenna_b.shape[0],lenna_b.shape[1])*max(lenna_b)/10
plt.imshow(np.reshape(lenna_n,[lenna_dim,lenna_dim]),cmap='gray')
# Out:
# (2916, 1)

# %%
# total variation matrix
def TV(dim):
    M1 = np.eye(dim-1,dim,0)
    M2 = np.eye(dim-1,dim,1)
    return M1 - M2
# objective
def H(A,b,M):
    def h(u):
        return np.linalg.norm(np.dot(A,u)-b)**2 + np.sum(np.fabs(np.dot(M,u)))
    return h

# %%
# actual problem
M = TV(lenna_dim**2)
h = H(A,lenna_n,M)

# %%
# prox operator
def prox(x):
    d = np.shape(x)
    y=x
    for j in range(0,d[0]):
        if x[j,0] > 1:
            y[j,0] = 1
            
        elif x[j,0] < -1:
            y[j,0] = -1
    return(y)

# %%
# multi prox papc implementation for lenna tests
def papc(L,A,b,M,N,v0,u0,t,s,A2):
    
    # initialization
    v = v0
    u = u0
    Mt = np.transpose(M)
    Ab = np.dot(np.transpose(A),b)
    V = []
    U = []
    print(t)
    return 0
    # iterations
    for i in range(0,N):
        p = u
        for j in range(0,L):
            p = p-t*(np.dot(Mt,v) + 2*np.dot(A2,p) - 2*Ab )
            a = v + s*np.dot(M,p)
            v = prox(a)
        u = u-t*(np.dot(Mt,v) + 2*np.dot(A2,u) - 2*Ab )
        V.append(v)
        U.append(u)
        
        
    return{'V':V,'U':U,'optval':None}

# %%
# PAPC preliminary
import time as time
t0 = time.time()
u0 = np.zeros(lenna_n.shape)
v0 = np.dot(M,u0)
A2 = np.dot(np.transpose(A),A)
t = 1/(2*np.linalg.norm(A2,2))
print('t:',t,'\n')
if t > 1:
    t = np.random.rand(1)
    print('t:',t,'\n')
t1 = time.time()
print('time:',t1 - t0,'\n')
s = t*(np.linalg.norm(M,2))**2
t2 = time.time()
print('s:',s,'\ntime:',t2-t1,'\n')
# Out:
# t: 0.000208248494834
#
# time: 106.63013982772827
#
# s:
#  0.00083299373762
# time: 65.49040293693542
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f3c531586ced> in <module>()
#      15 t2 = time.time()
#      16 print('s:',s,'\ntime:',t2-t1,'\n')
# ---> 17 R = papc(1,A,lenna_n,M,1,v0,u0)
#      18 print('papc\ntime:',time.time()-t2,'\n')
#
# TypeError: papc() missing 2 required positional arguments: 't' and 's'

# %%
# actual PAPC run
t0 = time.time()
R = papc(1,A,lenna_n,M,v0,u0,t,s,A2)
print('papc\ntime:',time.time()-t0,'\n')

# %% [markdown]
# ## Bibliography
# [DST15] - A simple algorithm for a class of nonsmooth convex–concave saddle-point problems.
# Teboulle M, Drori Y, Sabach S. Operation Research Letters 2015
